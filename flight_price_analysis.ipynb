# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset into a Pandas DataFrame
df=pd.read_csv('economy.csv')

# %%
# Expl0re data
df.head()
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price
# 0  non-stop     21:05  Mumbai  5,953
# 1  non-stop     08:40  Mumbai  5,953
# 2  non-stop     06:35  Mumbai  5,956
# 3  non-stop     12:35  Mumbai  5,955
# 4  non-stop     11:10  Mumbai  5,955

# %%
df.tail()
# Out:
#               date  airline ch_code  num_code dep_time     from time_taken  \
# 206769  31-03-2022  Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022  Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022  Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022  Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022  Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 206769  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206770  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206771  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206772  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206773  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
#
#         price
# 206769  7,697
# 206770  7,709
# ...

# %%
df.shape
# Out:
# (206774, 11)

# %%
df.columns
# Out:
# Index(['date', 'airline', 'ch_code', 'num_code', 'dep_time', 'from',
#        'time_taken', 'stop', 'arr_time', 'to', 'price'],
#       dtype='object')

# %%
# Check for missing values
df.isnull().sum()
# Out:
# date          0
# airline       0
# ch_code       0
# num_code      0
# dep_time      0
# from          0
# time_taken    0
# stop          0
# arr_time      0
# to            0
# price         0
# dtype: int64

# %%
# convet date column to datetime
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')

# %%
# extract day of week in a seperate column
df['day'] = df['date'].dt.day_name()

# %%
# remove commas from price
df['price'] = df['price'].str.replace(',', '').astype(int)

# %%
# summary stats
df.describe()
# Out:
#                                 date       num_code          price
# count                         206774  206774.000000  206774.000000
# mean   2022-03-08 02:57:25.083037440    1706.096714    6571.190701
# min              2022-02-11 00:00:00     101.000000    1105.000000
# 25%              2022-02-25 00:00:00     588.000000    4173.000000
# 50%              2022-03-08 00:00:00     818.000000    5772.000000
# 75%              2022-03-20 00:00:00     960.000000    7746.000000
# max              2022-03-31 00:00:00    9991.000000   42349.000000
# std                              NaN    2320.463721    3743.442838

# %%
# explore data with changes
df.head()
# Out:
#         date   airline ch_code  num_code dep_time   from time_taken  \
# 0 2022-02-11  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1 2022-02-11  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2 2022-02-11   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3 2022-02-11   Vistara      UK       995    10:20  Delhi    02h 15m
# 4 2022-02-11   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price     day
# 0  non-stop     21:05  Mumbai   5953  Friday
# 1  non-stop     08:40  Mumbai   5953  Friday
# 2  non-stop     06:35  Mumbai   5956  Friday
# 3  non-stop     12:35  Mumbai   5955  Friday
# 4  non-stop     11:10  Mumbai   5955  Friday

# %%
df.tail()
# Out:
#              date  airline ch_code  num_code dep_time     from time_taken  \
# 206769 2022-03-31  Vistara      UK       832    07:05  Chennai    13h 50m
# 206770 2022-03-31  Vistara      UK       832    07:05  Chennai    13h 50m
# 206771 2022-03-31  Vistara      UK       826    12:30  Chennai    20h 35m
# 206772 2022-03-31  Vistara      UK       822    09:45  Chennai    23h 20m
# 206773 2022-03-31  Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 206769  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206770  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206771  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206772  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206773  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
#
#         price       day
# 206769   7697  Thursday
# ...

# %%
# Average price per day
price_per_day = df.groupby('day')['price'].mean().sort_values()
print(price_per_day)
# Out:
# day
# Tuesday      6208.377776
# Wednesday    6281.351764
# Monday       6314.291882
# Thursday     6333.411344
# Sunday       6953.467693
# Friday       6970.399942
# Saturday     7008.861118
# Name: price, dtype: float64

# %%
# Average price per airline
avg_airline_price = df.groupby('airline')['price'].mean().sort_values()
print(avg_airline_price)
# Out:
# airline
# Trujet       3244.634146
# AirAsia      4091.072742
# StarAir      4932.655738
# Indigo       5324.216303
# GO FIRST     5651.930578
# SpiceJet     6179.278881
# Air India    7313.730144
# Vistara      7806.943645
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x='day', y='price', data=df, order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Ticket Prices by day')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x='day', y='price', data=df, estimator='mean', errorbar=None)
plt.title('Average Ticket Price Per Day')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='day', y='price', hue='airline', data=df)
plt.title('Comparison of Average Prices Across Airlines by Day')
plt.xticks(rotation=45)
plt.legend(title='Airline', bbox_to_anchor=(1, 1))
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['price'], bins=50, kde=True)
plt.title('Distribution of Ticket Prices')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='day', y='price', hue='airline', estimator='mean', errorbar=None)
plt.title('Average Ticket Prices of Each Airline Per Day')
plt.xticks(rotation=45)
plt.legend(title='Airline', bbox_to_anchor=(1, 1))
plt.show()

# %%
cheapest_day = price_per_day.idxmin()
most_expensive = price_per_day.idxmax()
cheapest_airline = avg_airline_price.idxmin()
expensive_airline = avg_airline_price.idxmax()

# %%
print(f"Cheapest day to book flights: {cheapest_day}")
print(f"Most expensive day to book flights: {most_expensive}")
print(f"Cheapest airline: {cheapest_airline}")
print(f"Most expensive airline: {expensive_airline}")
# Out:
# Cheapest day to book flights: Tuesday
# Most expensive day to book flights: Saturday
# Cheapest airline: Trujet
# Most expensive airline: Vistara

# %%
# missing day on airline
